# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
MF = pd.read_excel(r'/content/drive/MyDrive/AIML/Mutual_Funds_Sht_list20.xlsx')
MF
# Out:
#          Date  PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# 0  2020-04-17             124.39             132.46             125.93
# 1  2020-04-24             124.39             132.46             125.93
# 2  2020-05-01             125.93             132.19             126.97
# 3  2020-05-08             125.93             132.19             126.97
# 4  2020-05-15             125.93             132.19             126.97
# ..        ...                ...                ...                ...
# 91 2022-01-14             182.56             175.93             166.95
# 92 2022-01-21             182.56             175.93             166.95
# 93 2022-01-28             182.56             175.93             166.95
# 94 2022-02-04             182.56             175.93             166.95
# 95 2022-02-11             182.56             175.93             166.95
#
#     PFARAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# ...

# %% [markdown]
# # In the below code we have changed the data type of date column to datetime64

# %%
MF['Date'] = pd.to_datetime(MF['Date'], format ='%d/m%/%Y')
MF['Date']
# Out:
# 0    2020-04-17
# 1    2020-04-24
# 2    2020-05-01
# 3    2020-05-08
# 4    2020-05-15
#         ...
# 91   2022-01-14
# 92   2022-01-21
# 93   2022-01-28
# 94   2022-02-04
# 95   2022-02-11
# Name: Date, Length: 96, dtype: datetime64[ns]

# %%
 MF.set_index('Date', inplace = True)

# %%
# Plot the adjusted close price
MF.plot(figsize=(16, 9))
# Define the label for the title of the figure
plt.title("Adjusted Close Price of Mutual Funds" % MF, fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Adj Close Price', fontsize=14) 
plt.xlabel('Year', fontsize=14)
# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
# Log of percentage change of all Mutual Funds in the list
Ret= MF.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN 
Ret.head()
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# Date
# 2020-04-17                NaN                NaN                NaN
# 2020-04-24           0.000000            0.00000           0.000000
# 2020-05-01           0.012304           -0.00204           0.008225
# 2020-05-08           0.000000            0.00000           0.000000
# 2020-05-15           0.000000            0.00000           0.000000
#
#             PFARAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# Date
# 2020-04-17                NaN                NaN                NaN
# 2020-04-24           0.000000           0.000000           0.000000
# 2020-05-01           0.007066           0.005792          -0.019022
# 2020-05-08           0.000000           0.000000           0.000000
# 2020-05-15           0.000000           0.000000           0.000000
#
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# Date
# ...

# %%
Ret.plot(title='Mutual Funds weekly returns')

# %%
Ann_Ret = Ret.mean()*52 
print (Ann_Ret)
# Out:
# PFGDAAU LX Equity    0.210002
# PFTEAAU LX Equity    0.155346
# PFCSAAU LX Equity    0.154340
# PFARAAU LX Equity    0.148201
# PFBKAAU LX Equity    0.139987
# PFGOAAU LX Equity    0.124551
# AIBALMA AB Equity    0.164994
# LODFUIA LX Equity    0.020183
# CCASORI MK Equity    0.077905
# CCASLTF MK Equity    0.075863
# BBFTOP3 KY Equity    0.059322
# CRLCBUU LX Equity    0.047072
# BCUSDLF KK Equity    0.007076
# GMFDEBI LE Equity    0.009849
# PGPGIFA ID Equity    0.061577
# BLUESPH BM Equity    0.056085
# PFGLAAU LX Equity    0.090445
# ALPCRDA LX Equity    0.091994
# ALCONGP AB Equity    0.051767
# UBSFLBI LX Equity    0.022493
# BUTIBLI KY Equity    0.135671
# PGPCBFA ID Equity    0.186455
# SCHGTRA LX Equity    0.094031
# dtype: float64

# %%
Ann_Risk = Ret.std()*(52)**(0.5) 
print(Ann_Risk)
# Out:
# PFGDAAU LX Equity    0.086571
# PFTEAAU LX Equity    0.053876
# PFCSAAU LX Equity    0.057654
# PFARAAU LX Equity    0.057355
# PFBKAAU LX Equity    0.062312
# PFGOAAU LX Equity    0.066725
# AIBALMA AB Equity    0.052010
# LODFUIA LX Equity    0.006843
# CCASORI MK Equity    0.016388
# CCASLTF MK Equity    0.016577
# BBFTOP3 KY Equity    0.011316
# CRLCBUU LX Equity    0.017065
# BCUSDLF KK Equity    0.002373
# GMFDEBI LE Equity    0.005989
# PGPGIFA ID Equity    0.022152
# BLUESPH BM Equity    0.046774
# PFGLAAU LX Equity    0.039963
# ALPCRDA LX Equity    0.027841
# ALCONGP AB Equity    0.043235
# UBSFLBI LX Equity    0.013572
# BUTIBLI KY Equity    0.080982
# PGPCBFA ID Equity    0.149274
# SCHGTRA LX Equity    0.046193
# dtype: float64

# %%
RF = 0.0148
Sharpe = (Ann_Ret - RF)/Ann_Risk
Sharpe
# Out:
# PFGDAAU LX Equity    2.254811
# PFTEAAU LX Equity    2.608695
# PFCSAAU LX Equity    2.420316
# PFARAAU LX Equity    2.325880
# PFBKAAU LX Equity    2.009026
# PFGOAAU LX Equity    1.644829
# AIBALMA AB Equity    2.887802
# LODFUIA LX Equity    0.786600
# CCASORI MK Equity    3.850720
# CCASLTF MK Equity    3.683550
# BBFTOP3 KY Equity    3.934353
# CRLCBUU LX Equity    1.891095
# BCUSDLF KK Equity   -3.255224
# GMFDEBI LE Equity   -0.826616
# PGPGIFA ID Equity    2.111617
# BLUESPH BM Equity    0.882654
# PFGLAAU LX Equity    1.892888
# ALPCRDA LX Equity    2.772634
# ALCONGP AB Equity    0.855021
# UBSFLBI LX Equity    0.566827
# BUTIBLI KY Equity    1.492575
# PGPCBFA ID Equity    1.149935
# SCHGTRA LX Equity    1.715203
# dtype: float64

# %%
assets = pd.concat([Ann_Ret, Ann_Risk, Sharpe], axis=1) # Creating a table for visualising returns and volatility of assets 
assets.columns = ['Returns', 'Volatility','Sharpe']
assets
# Out:
#                     Returns  Volatility    Sharpe
# PFGDAAU LX Equity  0.210002    0.086571  2.254811
# PFTEAAU LX Equity  0.155346    0.053876  2.608695
# PFCSAAU LX Equity  0.154340    0.057654  2.420316
# PFARAAU LX Equity  0.148201    0.057355  2.325880
# PFBKAAU LX Equity  0.139987    0.062312  2.009026
# PFGOAAU LX Equity  0.124551    0.066725  1.644829
# AIBALMA AB Equity  0.164994    0.052010  2.887802
# LODFUIA LX Equity  0.020183    0.006843  0.786600
# CCASORI MK Equity  0.077905    0.016388  3.850720
# CCASLTF MK Equity  0.075863    0.016577  3.683550
# BBFTOP3 KY Equity  0.059322    0.011316  3.934353
# CRLCBUU LX Equity  0.047072    0.017065  1.891095
# BCUSDLF KK Equity  0.007076    0.002373 -3.255224
# GMFDEBI LE Equity  0.009849    0.005989 -0.826616
# PGPGIFA ID Equity  0.061577    0.022152  2.111617
# BLUESPH BM Equity  0.056085    0.046774  0.882654
# PFGLAAU LX Equity  0.090445    0.039963  1.892888
# ALPCRDA LX Equity  0.091994    0.027841  2.772634
# ...

# %%
Ret_Corr = Ret.corr() 
Ret_Corr
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# PFGDAAU LX Equity           1.000000           0.799297           0.777878
# PFTEAAU LX Equity           0.799297           1.000000           0.909712
# PFCSAAU LX Equity           0.777878           0.909712           1.000000
# PFARAAU LX Equity           0.645585           0.868219           0.897823
# PFBKAAU LX Equity           0.579283           0.803664           0.907396
# PFGOAAU LX Equity           0.601038           0.667271           0.619391
# AIBALMA AB Equity          -0.018882           0.090318           0.020763
# LODFUIA LX Equity           0.464809           0.555566           0.426849
# CCASORI MK Equity          -0.284299          -0.305255          -0.287590
# CCASLTF MK Equity          -0.179611          -0.230801          -0.180454
# BBFTOP3 KY Equity          -0.163523          -0.173050          -0.304791
# ...

# %%
Ret_Covar = Ret.cov() 
(Ret_Covar)
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# PFGDAAU LX Equity       1.441265e-04       7.169259e-05       7.466376e-05
# PFTEAAU LX Equity       7.169259e-05       5.581974e-05       5.434057e-05
# PFCSAAU LX Equity       7.466376e-05       5.434057e-05       6.392238e-05
# PFARAAU LX Equity       6.164450e-05       5.159314e-05       5.709341e-05
# PFBKAAU LX Equity       6.009461e-05       5.188493e-05       6.268971e-05
# PFGOAAU LX Equity       6.676647e-05       4.612973e-05       4.582220e-05
# AIBALMA AB Equity      -1.634953e-06       4.866868e-06       1.197295e-06
# LODFUIA LX Equity       5.295693e-06       3.939181e-06       3.238748e-06
# CCASORI MK Equity      -7.756574e-06      -5.182977e-06      -5.225434e-06
# CCASLTF MK Equity      -4.956937e-06      -3.964062e-06      -3.316667e-06
# BBFTOP3 KY Equity      -3.080687e-06      -2.028898e-06      -3.824050e-06
# ...

# %%
corr_matrix = MF.pct_change().apply(lambda x: np.log(1+x)).corr() 
corr_matrix
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# PFGDAAU LX Equity           1.000000           0.799297           0.777878
# PFTEAAU LX Equity           0.799297           1.000000           0.909712
# PFCSAAU LX Equity           0.777878           0.909712           1.000000
# PFARAAU LX Equity           0.645585           0.868219           0.897823
# PFBKAAU LX Equity           0.579283           0.803664           0.907396
# PFGOAAU LX Equity           0.601038           0.667271           0.619391
# AIBALMA AB Equity          -0.018882           0.090318           0.020763
# LODFUIA LX Equity           0.464809           0.555566           0.426849
# CCASORI MK Equity          -0.284299          -0.305255          -0.287590
# CCASLTF MK Equity          -0.179611          -0.230801          -0.180454
# BBFTOP3 KY Equity          -0.163523          -0.173050          -0.304791
# ...

# %%
import seaborn as sns

# %%
from IPython.core.pylabtools import figsize
sns.set(rc={'figure.figsize':(20, 20)})
sns.heatmap(corr_matrix, annot=True, vmin=0.2)

# %%
# Randomly weighted portfolio's variance
w = (0.125)
Ann_port_std = (port_var*52)**(0.5)
print (port_var)
print (port_var*52)
# Out:
# 7.363312432714312e-05
# 0.0038289224650114423

# %%
# Yearly returns for individual companies
ind_er = MF.resample('Y').last().pct_change().mean()
ind_er
# Out:
# PFGDAAU LX Equity    0.145453
# PFTEAAU LX Equity    0.121749
# PFCSAAU LX Equity    0.109440
# PFARAAU LX Equity    0.100191
# PFBKAAU LX Equity    0.092993
# PFGOAAU LX Equity    0.078892
# AIBALMA AB Equity    0.076369
# LODFUIA LX Equity    0.013253
# CCASORI MK Equity    0.038140
# CCASLTF MK Equity    0.038412
# BBFTOP3 KY Equity    0.040926
# CRLCBUU LX Equity    0.022385
# BCUSDLF KK Equity    0.002768
# GMFDEBI LE Equity    0.006226
# PGPGIFA ID Equity    0.021034
# BLUESPH BM Equity    0.014902
# PFGLAAU LX Equity    0.038815
# ALPCRDA LX Equity    0.019602
# ALCONGP AB Equity    0.017065
# UBSFLBI LX Equity    0.004839
# BUTIBLI KY Equity    0.049820
# PGPCBFA ID Equity    0.023058
# SCHGTRA LX Equity    0.021886
# dtype: float64

# %%
my_list=['PFGDAAU LX Equity','PFTEAAU LX Equity','PFCSAAU LX Equity', 'PFARAAU LX Equity','LODFUIA LX Equity','SCHGTRA LX Equity','ALPCRDA LX Equity','CCASORI MK Equity']
Clean_MF = MF[my_list]

Ret = Clean_MF.pct_change().apply(lambda x: np.log(1+x))

Ann_Returns = Ret.mean()*52
Ann_Risk = Ret.std()*(52)**(0.5) 
RF = 0.0148
Sharpe = (Ann_Ret - RF)/Ann_Risk
Ret_Corr = Ret.corr()
Ret_Covar = Ret.cov()

# %%
Clean_MF
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# Date
# 2020-04-17             124.39             132.46             125.93
# 2020-04-24             124.39             132.46             125.93
# 2020-05-01             125.93             132.19             126.97
# 2020-05-08             125.93             132.19             126.97
# 2020-05-15             125.93             132.19             126.97
# ...                       ...                ...                ...
# 2022-01-14             182.56             175.93             166.95
# 2022-01-21             182.56             175.93             166.95
# 2022-01-28             182.56             175.93             166.95
# 2022-02-04             182.56             175.93             166.95
# 2022-02-11             182.56             175.93             166.95
#
#             PFARAAU LX Equity  LODFUIA LX Equity  SCHGTRA LX Equity  \
# Date
# ...

# %%
# Portfolio returns
w = [12.5] 
port_er = (w*ind_er[my_list]).sum()
port_er
# Out:
# 7.12142585907013

# %%
import matplotlib.pyplot as plt 
x = Ann_Risk # RISK
y = Ann_Returns # Return 
plt.scatter(x, y)
plt.show()

# %%
# Volatility is given by the annual standard deviation. We multiply by 252 because there are 252 trading days/year.
ann_sd = Clean_MF.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(52)) 
ann_sd
# Out:
# PFGDAAU LX Equity    0.086571
# PFTEAAU LX Equity    0.053876
# PFCSAAU LX Equity    0.057654
# PFARAAU LX Equity    0.057355
# LODFUIA LX Equity    0.006843
# SCHGTRA LX Equity    0.046193
# ALPCRDA LX Equity    0.027841
# CCASORI MK Equity    0.016388
# dtype: float64

# %%
p_ret = [] # Define an empty array for portfolio returns 
p_vol = [] # Define an empty array for portfolio volatility 
p_shar = []
p_weights = [] # Define an empty array for asset weights
num_assets = len(Clean_MF.columns) 
num_portfolios = 100000

# %%
for portfolio in range(num_portfolios): 
    weights = np.random.random(num_assets) 
    weights = weights/np.sum(weights) 
    p_weights.append(weights)
    returns = np.dot(weights, Ann_Returns) # Returns are the product of individual expected returns of asset and its # weights
    
    p_ret.append(returns)
    var = Ret_Covar.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance 
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(52) #Annual standard deviation = volatility 
    p_vol.append(ann_sd)
    sharpe = returns/ann_sd
    p_shar.append(sharpe)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol, 'Sharpe':p_shar}

for counter, symbol in enumerate(Clean_MF.columns.tolist()): 
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility    Sharpe  PFGDAAU LX Equity weight  \
# 0  0.115178    0.026406  4.361823                  0.085926
# 1  0.134507    0.037424  3.594146                  0.301013
# 2  0.125267    0.029821  4.200568                  0.109426
# 3  0.123631    0.035242  3.508042                  0.162698
# 4  0.105947    0.024597  4.307298                  0.007484
#
#    PFTEAAU LX Equity weight  PFCSAAU LX Equity weight  \
# 0                  0.147315                  0.147467
# 1                  0.095116                  0.019657
# 2                  0.125700                  0.227596
# 3                  0.132182                  0.200350
# 4                  0.118310                  0.042909
#
#    PFARAAU LX Equity weight  LODFUIA LX Equity weight  \
# 0                  0.037460                  0.085684
# 1                  0.121329                  0.078442
# 2                  0.002148                  0.010020
# ...

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()] 
# idxmin() gives us the minimum value in the column specified. 
min_vol_port
# Out:
# Returns                     0.065918
# Volatility                  0.010018
# Sharpe                      6.580069
# PFGDAAU LX Equity weight    0.014635
# PFTEAAU LX Equity weight    0.030804
# PFCSAAU LX Equity weight    0.003346
# PFARAAU LX Equity weight    0.026822
# LODFUIA LX Equity weight    0.366854
# SCHGTRA LX Equity weight    0.099062
# ALPCRDA LX Equity weight    0.080266
# CCASORI MK Equity weight    0.378211
# Name: 97495, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[6,5])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3) 
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()] 
optimal_risky_port
# Out:
# Returns                     0.081016
# Volatility                  0.011867
# Sharpe                      6.827213
# PFGDAAU LX Equity weight    0.028188
# PFTEAAU LX Equity weight    0.011203
# PFCSAAU LX Equity weight    0.075677
# PFARAAU LX Equity weight    0.046898
# LODFUIA LX Equity weight    0.220884
# SCHGTRA LX Equity weight    0.030136
# ALPCRDA LX Equity weight    0.120818
# CCASORI MK Equity weight    0.466196
# Name: 18689, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3) 
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500) 
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
